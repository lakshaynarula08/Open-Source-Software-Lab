# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshaynarula08/Open-Source-Software-Lab/blob/main/9918103075_OSS_LAB_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OSS LAB ASSIGNMENT-5
#
# **LAKSHAY NARULA
# 9918103075    F3**

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
import matplotlib.pyplot as plt
plt.plot(X, C)
plt.plot(X, S)
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=80)

# %%
plt.subplot(1, 1, 1)

# %%
plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# %%
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))
plt.savefig("sine_cosine.png", dpi=72)

# %%
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")
plt.legend(loc='upper left')

# %%
n = 256
X = np.linspace(-np.pi, np.pi, n, endpoint=True)
Y = np.sin(2 * X)
plt.plot(X, Y + 1, color='blue', alpha=1.00)
plt.plot(X, Y - 1, color='blue', alpha=1.00)

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
plt.scatter(X,Y)

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.show()
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
plt.show()

# %% [markdown]
# PRACTICE QUESTIONS

# %% [markdown]
# **Q2**

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = ['A', 'B', 'C', 'D']
res1 = [2, 5, 8, 5]
res2 = [3, 2, 5, 7]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, res1, 0.4, label = 'res1')
plt.bar(X_axis + 0.2, res2, 0.4, label = 'res2')
  
plt.xticks(X_axis, X)
plt.title("Method Comparision")
plt.xlabel("Groups")
plt.ylabel("Results")
plt.legend()
plt.show()

# %% [markdown]
# **Q1**

# %%
import numpy as np
import matplotlib.pyplot as plt
x= [-np.pi, -np.pi/2,-np.pi/4, 0, np.pi/4, np.pi/2, np.pi]
plt.plot(np.tan(x))

# %%
plt.plot(1/np.tan(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(1/np.sin(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(1/np.cos(x))
